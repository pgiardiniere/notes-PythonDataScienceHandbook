# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
plt.style.use('seaborn-whitegrid')

fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# The figure isntance can be thought of as a container,
# with all the objects representing  axes, graphics, text, and labels inside.
#
# The axes in instance ax are bouding boxes with ticks/labels,
# which go on to contain the plot elements of the visualization.

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %% [markdown]
# Huh, so importantly I DO need to have a redeclaration of fig, ax in the above cell
#
# Actually, that makes sense. Figures are 1-shot and done in this library if I recall correctly.

# %% [markdown]
# Alternatively, if we want to display plots using the Matlab-style stateful way...

# %%
plt.plot(x, np.sin(x))

# %%
# Create a single figure with multiple lines in Matlab-like way

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
